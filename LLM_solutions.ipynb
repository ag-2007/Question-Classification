# %% [markdown]
# ## Importing data from JSON files

# %%
import json
from pathlib import Path

# %%
def load_split(split_path):
    texts = []
    labels = []

    for topic_dir in split_path.iterdir():
        if topic_dir.is_dir():
            label = topic_dir.name  # folder name = class label

            for json_file in topic_dir.glob("*.json"):
                with open(json_file, "r", encoding="utf-8") as f:
                    data = json.load(f)
                    texts.append(data["problem"])
                    labels.append(label)

    return texts, labels


base_dir = Path("C:/Users/anika/OneDrive/Desktop/Anika/College/CSI/Task_1/MATH")

X_train, y_train = load_split(base_dir / "train")
X_test, y_test = load_split(base_dir / "test")

print(f"Train samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")
print("Example:", X_train[0], "->", y_train[0])
# Out:
# Train samples: 7500
# Test samples: 5000
# Example: Let \[f(x) = \left\{
# \begin{array}{cl} ax+3, &\text{ if }x>2, \\
# x-5 &\text{ if } -2 \le x \le 2, \\
# 2x-b &\text{ if } x <-2.
# \end{array}
# \right.\]Find $a+b$ if the piecewise function is continuous (which means that its graph can be drawn without lifting your pencil from the paper). -> algebra

# %% [markdown]
# ## LLM Solutions

# %%
sample_questions = X_test[:5]

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key="YOUR_API_KEY")

def generate_solution(question):
    prompt = f"""
You are a high school math tutor.
Solve the following question step by step.
Explain each step clearly and simply,
as if teaching a student seeing this concept for the first time.

Question:
{question}
"""

    completion = client.chat.completions.create(
        model="moonshotai/Kimi-K2-Instruct-0905",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.2,
        max_tokens=500
    )

    return completion.choices[0].message.content

# %%
for i in range(5):
    print("\n" + "=" * 80)
    print(f"Question {i + 1}")
    print("-" * 80)
    print(sample_questions[i])
    print("\nSolution:")
    print("-" * 80)

    sol = generate_solution(sample_questions[i])
    print(sol.strip())

    print("=" * 80 + "\n")
# Out:
# ================================================================================
# Question 1
# --------------------------------------------------------------------------------
# How many vertical asymptotes does the graph of $y=\frac{2}{x^2+x-6}$ have?
#
# Solution:
# --------------------------------------------------------------------------------
# Let’s treat this like we’re seeing it for the first time.
#
# Step 1 – What is a vertical asymptote?
# A vertical asymptote is a vertical line x = a where the y-values of the function “blow up” to ±∞.  For a rational (fraction) function, that happens exactly where the denominator is 0 and the numerator is NOT 0.
#
# Step 2 – Identify the denominator.
# The function is
#
# y = 2 / (x² + x – 6)
#
# The denominator is x² + x – 6.
#
# Step 3 – Find where the denominator is zero.
# Set the denominator equal to 0 and solve:
#
# x² + x – 6 = 0
#
# Factor:
# (x + 3)(x – 2) = 0
#
# So x = –3 or x = 2.
#
# Step 4 – Check that the numerator is not zero at those spots.
# The numerator is the constant 2, which is never 0.  Therefore both places give vertical asymptotes.
#
# Step 5 – Count them.
# We found two different x-values (–3 and 2) that make the denominator 0 and the numerator non-zero.
#
# Answer: 2 vertical asymptotes.
# ================================================================================
#
#
# ================================================================================
# Question 2
# --------------------------------------------------------------------------------
# What is the positive difference between $120\%$ of 30 and $130\%$ of 20?
#
# Solution:
# --------------------------------------------------------------------------------
# Let’s break this down step-by-step so you can see exactly what each phrase means and how to find the “positive difference.”
#
# Step 1: Understand “120 % of 30”
# “Percent” means “per hundred,” so 120 % = 120⁄100 = 1.2.
# Multiply: 1.2 × 30 = 36.
#
# Step 2: Understand “130 % of 20”
# 130 % = 130⁄100 = 1.3.
# Multiply: 1.3 × 20 = 26.
#
# Step 3: Find the positive difference
# Positive difference just means subtract the smaller number from the larger one and drop any minus sign.
# 36 − 26 = 10.
#
# Answer: 10
# ================================================================================
#
#
# ================================================================================
# Question 3
# --------------------------------------------------------------------------------
# Find $x$ such that $\lceil x \rceil + x = \dfrac{23}{7}$. Express $x$ as a common fraction.
#
# Solution:
# --------------------------------------------------------------------------------
# Let’s break this down step-by-step so you can see exactly how to get from the ceiling equation to a simple fraction.
#
# -------------------------------------------------
# Step 1.  Understand the ceiling symbol
# The ceiling of a real number, written ⌈x⌉, is the smallest integer that is ≥ x.
# Examples:
# - ⌈3.2⌉ = 4
# - ⌈5⌉ = 5
# - ⌈–2.3⌉ = –2
#
# -------------------------------------------------
# Step 2.  Give the unknown integer a name
# Let
# n = ⌈x⌉.
# Because n is an integer, we can write the given equation as
#
# n + x = 23⁄7.                     (1)
#
# -------------------------------------------------
# Step 3.  Solve (1) for x
# x = 23⁄7 – n.                     (2)
#
# -------------------------------------------------
# Step 4.  Use the definition of ceiling
# Since n = ⌈x⌉, we must have
#
# n – 1 < x ≤ n.                    (3)
#
# Substitute (2) into (3):
#
# n – 1 < 23⁄7 – n ≤ n.
#
# -------------------------------------------------
# Step 5.  Solve the two inequalities
#
# Left inequality:
# n – 1 < 23⁄7 – n
# 2n < 23⁄7 + 1 = 30⁄7
# n < 15⁄7 ≈ 2.14.
#
# Right inequality:
# 23⁄7 – n ≤ n
# 23⁄7 ≤ 2n
# n ≥ 23⁄14 ≈ 1.64.
#
# -------------------------------------------------
# Step 6.  Pick the only integer in that interval
# 1.64 ≤ n < 2.14  ⇒  n = 2.
#
# -------------------------------------------------
# Step 7.  Find x
# Put n = 2 back into (2):
#
# x = 23⁄7 – 2
#   = 23⁄7 – 14⁄7
#   = 9⁄7.
#
# -------------------------------------------------
# Step 8.  Quick check
# ⌈9⁄7⌉ = ⌈1.2857…⌉ = 2, and
# 2 + 9⁄7 = 23⁄7 ✓
#
# -------------------------------------------------
# Answer
# x = 9⁄7.
# ================================================================================
#
#
# ================================================================================
# Question 4
# --------------------------------------------------------------------------------
# Evaluate $i^5+i^{-25}+i^{45}$.
#
# Solution:
# --------------------------------------------------------------------------------
# Let’s treat the powers of i one at a time, using the simple repeating cycle of i:
#
# i¹ = i
# i² = –1
# i³ = –i
# i⁴ = 1
# and then it repeats every 4 powers.
#
# Step 1: Reduce each exponent mod 4
# - 5 mod 4 = 1
# - –25 mod 4 = 3 (because –25 + 28 = 3)
# - 45 mod 4 = 1
#
# Step 2: Replace each power with its cycle value
# - i⁵ = i¹ = i
# - i⁻²⁵ = i³ = –i
# - i⁴⁵ = i¹ = i
#
# Step 3: Add the three results
# i + (–i) + i = (i – i) + i = 0 + i = i
#
# Answer: i
# ================================================================================
#
#
# ================================================================================
# Question 5
# --------------------------------------------------------------------------------
# If $2^8=4^x$, what is the value of $x$?
#
# Solution:
# --------------------------------------------------------------------------------
# Let’s solve this step-by-step, as if we’re seeing exponents for the very first time.
#
# 1.  **Understand the equation**
#     We are given
#     2⁸ = 4ˣ
#     We want to find the number x that makes this true.
#
# 2.  **Make the bases the same**
#     Right now the bases are 2 and 4.
#     Notice that 4 is just 2 × 2, so
#     4 = 2²
#     Replace 4 with 2² in the equation:
#
#     2⁸ = (2²)ˣ
#
# 3.  **Use the “power-of-a-power” rule**
#     When you raise a power to another power, you multiply the exponents:
#     (2²)ˣ = 2^(2·x) = 2^(2x)
#
#     So the equation becomes
#     2⁸ = 2^(2x)
#
# 4.  **Same base means same exponent**
#     If 2 to some power equals 2 to another power, the exponents must be equal:
#     8 = 2x
#
# 5.  **Solve for x**
#     Divide both sides by 2:
#     x = 8 ÷ 2 = 4
#
# 6.  **Quick check**
#     2⁸ = 256
#     4⁴ = (2²)⁴ = 2⁸ = 256 ✔️
#
# So the value of x is **4**.
# ================================================================================
